# %%
from langchain.agents import create_agent
from dotenv import load_dotenv

load_dotenv()

agent = create_agent(model="gemini-2.5-flash")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File d:\langchain-course\.venv\Lib\site-packages\google\cloud\aiplatform\initializer.py:367, in _Config.project(self)
#     366 try:
# --> 367     self._set_project_as_env_var_or_google_auth_default()
#     368     project_id = self._project
#
# File d:\langchain-course\.venv\Lib\site-packages\google\cloud\aiplatform\initializer.py:114, in _Config._set_project_as_env_var_or_google_auth_default(self)
#     113 else:
# --> 114     credentials, project = google.auth.default()
#     115     self._credentials = self._credentials or credentials
#
# File d:\langchain-course\.venv\Lib\site-packages\google\auth\_default.py:752, in default(scopes, request, quota_project_id, default_scopes)
#     750         return credentials, effective_project_id
# --> 752 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
#
# The above exception was the direct cause of the following exception:
#
# GoogleAuthError                           Traceback (most recent call last)
# Cell In[1], line 6
#       2 from dotenv import load_dotenv
#       4 load_dotenv()
# ----> 6 agent = create_agent(model="gemini-2.5-flash")
#
# File d:\langchain-course\.venv\Lib\site-packages\langchain\agents\factory.py:801, in create_agent(model, tools, system_prompt, middleware, response_format, state_schema, context_schema, checkpointer, store, interrupt_before, interrupt_after, debug, name, cache)
#     799 # init chat model
#     800 if isinstance(model, str):
# --> 801     model = init_chat_model(model)
#     803 # Convert system_prompt to SystemMessage if needed
#     804 system_message: SystemMessage | None = None
#
# File d:\langchain-course\.venv\Lib\site-packages\langchain\chat_models\base.py:464, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     456     warnings.warn(
#     457         f"{config_prefix=} has been set but no fields are configurable. Set "
#     458         f"`configurable_fields=(...)` to specify the model params that are "
#     459         f"configurable.",
#     460         stacklevel=2,
#     461     )
#     463 if not configurable_fields:
# --> 464     return _init_chat_model_helper(
#     465         cast("str", model),
#     466         model_provider=model_provider,
#     467         **kwargs,
#     468     )
#     469 if model:
#     470     kwargs["model"] = model
#
# File d:\langchain-course\.venv\Lib\site-packages\langchain\chat_models\base.py:488, in _init_chat_model_helper(model, model_provider, **kwargs)
#     486 model, model_provider = _parse_model(model, model_provider)
#     487 creator_func = _get_chat_model_creator(model_provider)
# --> 488 return creator_func(model=model, **kwargs)
#
# File d:\langchain-course\.venv\Lib\site-packages\langchain\chat_models\base.py:35, in _call(cls, **kwargs)
#      33 def _call(cls: type[BaseChatModel], **kwargs: Any) -> BaseChatModel:
#      34     # TODO: replace with operator.call when lower bounding to Python 3.11
# ---> 35     return cls(**kwargs)
#
# File d:\langchain-course\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:238, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     236     warned = True
#     237     emit_warning()
# --> 238 return wrapped(self, *args, **kwargs)
#
# File d:\langchain-course\.venv\Lib\site-packages\langchain_google_vertexai\chat_models.py:1859, in ChatVertexAI.__init__(self, model_name, **kwargs)
#    1853         suggestion = (
#    1854             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    1855         )
#    1856         logger.warning(
#    1857             f"Unexpected argument '{arg}' provided to ChatVertexAI.{suggestion}"
#    1858         )
# -> 1859 super().__init__(**kwargs)
#
# File d:\langchain-course\.venv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\langchain-course\.venv\Lib\site-packages\langchain_google_vertexai\_base.py:156, in _VertexAIBase.validate_project(self)
#     154         self.project = self.credentials.project_id
#     155     else:
# --> 156         self.project = initializer.global_config.project
#     157 return self
#
# File d:\langchain-course\.venv\Lib\site-packages\google\cloud\aiplatform\initializer.py:370, in _Config.project(self)
#     368     project_id = self._project
#     369 except GoogleAuthError as exc:
# --> 370     raise GoogleAuthError(project_not_found_exception_str) from exc
#     372 if not project_id and not self.api_key:
#     373     raise ValueError(project_not_found_exception_str)
#
# GoogleAuthError: Unable to find your project. Please provide a project ID by:
# - Passing a constructor argument
# - Using vertexai.init()
# - Setting project using 'gcloud config set project my-project'
# - Setting a GCP environment variable
# - To create a Google Cloud project, please follow guidance at https://developers.google.com/workspace/guides/create-project
